# %% [markdown]
# # Addestramento di RotatE con variante-NTU

# %%
# %cd ..

# %%
# %cd vsegreto1/KnowledgeGraphEmbedding_variant_NTU

# %%
# !bash run.sh train RotatE DBpedia100K 0  0 512 1024 500 12.0 0.5 0.0001 150000 8 -de
# Out:
# 2.2.1+cu118
# Start Training......
# 2024-03-03 11:33:43,420 INFO     Model: RotatE
# 2024-03-03 11:33:43,421 INFO     Data Path: data/DBpedia100K
# 2024-03-03 11:33:43,421 INFO     #entity: 99604
# 2024-03-03 11:33:43,421 INFO     #relation: 470
# 2024-03-03 11:33:43,937 INFO     #train: 597572
# 2024-03-03 11:33:43,976 INFO     #valid: 50000
# 2024-03-03 11:33:44,014 INFO     #test: 50000
# 2024-03-03 11:33:44,511 INFO     Model Parameter Configuration:
# 2024-03-03 11:33:44,512 INFO     Parameter gamma: torch.Size([1]), require_grad = False
# 2024-03-03 11:33:44,512 INFO     Parameter embedding_range: torch.Size([1]), require_grad = False
# 2024-03-03 11:33:44,512 INFO     Parameter entity_embedding: torch.Size([99604, 1000]), require_grad = True
# 2024-03-03 11:33:44,512 INFO     Parameter relation_embedding: torch.Size([470, 500]), require_grad = True
# 2024-03-03 11:33:52,734 INFO     Ramdomly Initializing RotatE Model...
# 2024-03-03 11:33:52,734 INFO     Start Training...
# ...

# %% [markdown]
# # Addestramento di RotatE con NTU

# %%
# %cd ..
# Out:
# /lustrehome/vsegreto1

# %%
# %cd KnowledgeGraphEmbedding_NTU

# %%
# !bash run.sh train RotatE DBpedia100K 0 0 512 1024 500 12.0 0.5 0.0001 150000 8 -de
# Out:
# 2.2.1+cu118
# Start Training......
# 2024-03-04 20:47:56,055 INFO     Model: RotatE
# 2024-03-04 20:47:56,056 INFO     Data Path: data/DBpedia100K
# 2024-03-04 20:47:56,056 INFO     #entity: 99604
# 2024-03-04 20:47:56,056 INFO     #relation: 470
# 2024-03-04 20:47:56,428 INFO     #train: 597572
# 2024-03-04 20:47:56,459 INFO     #valid: 50000
# 2024-03-04 20:47:56,490 INFO     #test: 50000
# 2024-03-04 20:47:56,977 INFO     Model Parameter Configuration:
# 2024-03-04 20:47:56,978 INFO     Parameter gamma: torch.Size([1]), require_grad = False
# 2024-03-04 20:47:56,978 INFO     Parameter embedding_range: torch.Size([1]), require_grad = False
# 2024-03-04 20:47:56,978 INFO     Parameter entity_embedding: torch.Size([99604, 1000]), require_grad = True
# 2024-03-04 20:47:56,978 INFO     Parameter relation_embedding: torch.Size([470, 500]), require_grad = True
# 2024-03-04 20:48:09,168 INFO     Ramdomly Initializing RotatE Model...
# 2024-03-04 20:48:09,168 INFO     Start Training...
# ...
